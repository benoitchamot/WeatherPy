# %% [markdown]
# # Assignment 6, Part 2: VacationPy

# %% [markdown]
# ## Import dependencies

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_api_key

# %% [markdown]
# ## Load data from CSV file

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     mata-utu -13.2816 -176.1745     26.68        75         100
# 1        1  egilsstadir  65.2653  -14.3948      6.18        91         100
# 2        2  grand-lahou   5.1367   -5.0242     24.04        92          98
# 3        3   ermoupolis  37.4423   24.9425     28.76        61           0
# 4        4     hamilton  39.1834  -84.5333     26.10        72          73
#
#    Wind Speed Country        Date
# 0        6.99      WF  1690336933
# 1        2.01      IS  1690336933
# 2        2.96      CI  1690336933
# 3        1.03      GR  1690336933
# 4        1.37      US  1690336711

# %% [markdown]
# ## Step 1
# Create a map that displays a point for every city in the city_data_df DataFrame. The size of the point should be the humidity in each city

# %%
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City"
)

map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ## Step 2
# Narrow down the city_data_df DataFrame to find your ideal weather condition

# %%
ideal_temp_min = 20
ideal_temp_max = 28
ideal_humi_max = 50
ideal_clouds = 10
ideal_wind_max = 5

ideal_city_data_df = city_data_df.loc[(city_data_df['Max Temp']>ideal_temp_min) &
                                    (city_data_df['Max Temp']<ideal_temp_max) &
                                    (city_data_df['Humidity']<ideal_humi_max) &
                                    (city_data_df['Cloudiness']<ideal_clouds) &
                                    (city_data_df['Wind Speed']<ideal_wind_max),:]

map_plot_2 = ideal_city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "City"
)

display(ideal_city_data_df)
map_plot_2
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 17        17                       kerman  30.2832   57.0788     26.68
# 79        79                      al jawf  29.5000   38.7500     26.55
# 146      146                    ouarzazat  30.9189   -6.8934     25.64
# 231      231                     qurayyat  31.3318   37.3428     26.70
# 232      232                         amga  60.8953  131.9608     25.41
# 249      249                      klyuchi  52.2667   79.1667     24.27
# 257      257                     qarazhal  48.0078   70.7903     26.82
# 366      366                       pocone -16.2567  -56.6228     24.50
# 403      403                  zmeinogorsk  51.1567   82.1950     23.43
# 459      459               oroqen zizhiqi  50.5667  123.7167     27.80
# 535      535                     toktogul  41.8708   72.9402     25.49
# 547      547                  zhezqazghan  47.7833   67.7667     22.32
# 561      561  posto fiscal rolim de moura -13.0833  -62.2667     22.87
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 17         13           1        0.59      IR  1690336938
# 79         29           5        3.66      SA  1690336957
# 146        31           0        1.39      MA  1690336977
# 231        34           0        2.28      SA  1690336883
# 232        34           4        3.49      RU  1690337003
# 249        40           8        1.90      RU  1690337009
# 257        29           8        3.17      KZ  1690337011
# 366        34           0        1.00      BR  1690337044
# 403        37           1        2.24      RU  1690337054
# 459        46           9        1.22      CN  1690337070
# 535        43           0        0.18      KG  1690337092
# 547        33           0        4.00      KZ  1690337095
# 561        49           0        0.54      BR  1690337099
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)
